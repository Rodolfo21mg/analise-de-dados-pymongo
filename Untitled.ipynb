# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\medllynthayna\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in c:\users\medllynthayna\anaconda3\lib\site-packages (from pymongo[srv]) (1.16.0)

# %%
import pymongo
import numpy as np
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://admin:JrngyDyKugA2pmM@cluster0.zbn9y.gcp.mongodb.net/test")

# %%
client.list_database_names()
# Out:
# ['anatel',
#  'covid',
#  'fifa',
#  'marinheiros',
#  'sample_analytics',
#  'tratamento_tabagismo',
#  'admin',
#  'local']

# %%
db = client.anatel

# %%
db.minas.count_documents({})
# Out:
# 131000

# %%
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5faed1ba84950429906a75f6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a75f7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5faed1ba84950429906a75f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1}]

# %%
list(db.list_collections())
# Out:
# [{'name': 'minas',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('4898b8c9-dde2-498c-b5b8-31e545cda02c')},
#   'idIndex': {'v': 2,
#    'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'anatel.minas'}}]

# %%
max = db.minas.aggregate([{"$group":{ "_id": {}, "max": {"$max": "$QtdeSolic"}}}])
valor = np.array(list(max))
max = valor[0]['max']

result = db.minas.aggregate([{"$match":{"QtdeSolic":{"$eq": max
}}}])

list(result)
# Out:
# [{'_id': ObjectId('5faed31784950429906c6f32'),
#   'DataExtracao': datetime.datetime(2016, 4, 19, 0, 0),
#   'Ano': 2013,
#   'Mes': 7,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 3000}]

# %%
result = db.minas.aggregate([{"$group":{ "_id": {}, "min": {"$min": "$QtdeSolic"}}}])
valor = np.array(list(result))
valor_minimo = valor[0]['min']
print(valor_minimo)
# Out:
# 1

# %%
result = db.minas.aggregate([{"$match":{"QtdeSolic":{"$eq": valor_minimo
}}}])

list(result)
# Out:
# [{'_id': ObjectId('5faed1ba84950429906a75f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7600'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7603'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7604'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7605'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7608'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a760b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a760e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a760f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7614'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7616'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio Comunitária',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7617'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a761a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a761c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7621'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7623'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7624'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Licenciamento e instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7627'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Resposta de solicitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7628'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7629'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7632'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7634'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7637'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7639'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a763a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a763b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7641'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7642'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a764b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a764c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7650'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7653'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7654'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7658'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7659'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a765b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Prestadoras',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a765c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a765d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a765f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7660'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7661'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7663'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7664'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7665'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7667'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a766a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a766b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a766c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a766d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a766e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Limitado Privado',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a766f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7670'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7674'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7675'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7676'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a767b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a767f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7682'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7685'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7686'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Atuação da Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7688'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7689'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a768a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a768c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a768e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7690'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7691'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7693'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7697'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7698'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'GVT',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7699'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a769b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a769e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a769f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76a5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76ac'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76ad'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76ae'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76b0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76b1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76b4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76b7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76b9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76be'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76c2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76c9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76ca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76ce'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76d3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76d5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76d6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interrupções no Serviço de Localidades',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76d9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76de'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76df'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76e2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76e9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76f6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7703'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7704'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7714'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7718'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a771e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7720'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7721'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7723'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7724'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7731'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7733'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7737'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7739'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a773b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a773d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7746'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7747'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Contrato de prestação de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7748'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7753'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7754'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
# ...
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d44'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d45'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d46'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d47'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d48'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d4c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d4e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Central de Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d4f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'MMDS (Via Microondas)',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d50'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d51'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d53'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Sala do Cidadão',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d54'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Documentos emitidos pela Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d55'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d57'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d5a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Produtos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d5b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Definição',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d5c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d5d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d5f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Portal Anatel',
#   'Motivo': 'Link Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d60'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d61'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d62'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d63'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d68'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d6b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d6d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d6e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d6f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d71'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d72'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d73'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d74'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d75'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d77'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d79'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d7a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d7b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d7d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d7e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d82'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7d83'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  ...]

# %%
count_servicos= db.minas.aggregate([{"$group":{"_id": "$Servico",
"Total": { "$sum": 1 } } } ]);
list(count_servicos)
# Out:
# [{'_id': 'Rádio do Cidadão (PX)', 'Total': 569},
#  {'_id': 'Troncalizado (Trunking)', 'Total': 404},
#  {'_id': 'Serviço Móvel Marítimo', 'Total': 20},
#  {'_id': 'Radiochamada (Paging)', 'Total': 22},
#  {'_id': 'Outros', 'Total': 810},
#  {'_id': 'Radiodifusão (Rádio e TV)', 'Total': 2048},
#  {'_id': 'Serviço Telefônico Fixo Comutado - STFC', 'Total': 32941},
#  {'_id': 'Limitado Privado', 'Total': 316},
#  {'_id': 'Serviço Móvel Aeronáutico', 'Total': 57},
#  {'_id': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Total': 531},
#  {'_id': 'Serviços da Anatel', 'Total': 3715},
#  {'_id': 'TV por Assinatura', 'Total': 17572},
#  {'_id': 'Radioamador (PY)', 'Total': 714},
#  {'_id': 'Móvel Pessoal', 'Total': 54852},
#  {'_id': 'Telefone Fixo', 'Total': 1},
#  {'_id': 'Serviço de Comunicação Multimídia', 'Total': 16428}]

# %%
result = db.minas.aggregate([{"$match":{"Tipo":{"$eq": "Reclamação"
}}}])

list(result)
# Out:
# [{'_id': ObjectId('5faed1ba84950429906a75f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a75fd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a75fe'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 9},
#  {'_id': ObjectId('5faed1ba84950429906a75ff'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 29},
#  {'_id': ObjectId('5faed1ba84950429906a7600'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7601'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a7602'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 12},
#  {'_id': ObjectId('5faed1ba84950429906a7603'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7604'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7605'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7606'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 10},
#  {'_id': ObjectId('5faed1ba84950429906a7607'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5faed1ba84950429906a7608'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7609'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a760a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 15},
#  {'_id': ObjectId('5faed1ba84950429906a760b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a760c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 7},
#  {'_id': ObjectId('5faed1ba84950429906a760d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a760e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a760f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7610'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a7611'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5faed1ba84950429906a7612'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cartão Telefônico',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5faed1ba84950429906a7613'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a7628'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7629'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a762c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a762f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7630'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a7631'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a7632'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7633'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a7634'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7635'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a7636'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1ba84950429906a7637'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7638'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5faed1ba84950429906a7639'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a763a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a763b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a763c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a763d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5faed1ba84950429906a763e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5faed1ba84950429906a763f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 62},
#  {'_id': ObjectId('5faed1ba84950429906a7640'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1ba84950429906a7641'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7642'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a7643'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic':
),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5faed1ba84950429906a76c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1ba84950429906a76c7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 22},
#  {'_id': ObjectId('5faed1ba84950429906a76c8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 14},
#  {'_id': ObjectId('5faed1ba84950429906a76c9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
# ...
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7ac8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 22},
#  {'_id': ObjectId('5faed1bc84950429906a7ac9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 58},
#  {'_id': ObjectId('5faed1bc84950429906a7aca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 26},
#  {'_id': ObjectId('5faed1bc84950429906a7acb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 71},
#  {'_id': ObjectId('5faed1bc84950429906a7acc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1bc84950429906a7acd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 44},
#  {'_id': ObjectId('5faed1bc84950429906a7ace'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5faed1bc84950429906a7acf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5faed1bc84950429906a7ad0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5faed1bc84950429906a7ad1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1bc84950429906a7ad2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 10},
#  {'_id': ObjectId('5faed1bc84950429906a7ad3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 147},
#  {'_id': ObjectId('5faed1bc84950429906a7ad4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 5},
#  {'_id': ObjectId('5faed1bc84950429906a7ad5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 38},
#  {'_id': ObjectId('5faed1bc84950429906a7ad7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 16},
#  {'_id': ObjectId('5faed1bc84950429906a7ad8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 107},
#  {'_id': ObjectId('5faed1bc84950429906a7ad9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 47},
#  {'_id': ObjectId('5faed1bc84950429906a7ada'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7adb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1bc84950429906a7adc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 12},
#  {'_id': ObjectId('5faed1bc84950429906a7add'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 18},
#  {'_id': ObjectId('5faed1bc84950429906a7ade'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7adf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 7},
#  {'_id': ObjectId('5faed1bc84950429906a7ae0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 72},
#  {'_id': ObjectId('5faed1bc84950429906a7ae1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1bc84950429906a7ae2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 83},
#  {'_id': ObjectId('5faed1bc84950429906a7ae3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 4},
#  {'_id': ObjectId('5faed1bc84950429906a7ae4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 92},
#  {'_id': ObjectId('5faed1bc84950429906a7ae5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 11},
#  {'_id': ObjectId('5faed1bc84950429906a7ae6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 13},
#  {'_id': ObjectId('5faed1bc84950429906a7ae7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7ae8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7ae9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1bc84950429906a7aea'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1bc84950429906a7aeb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7aec'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5faed1bc84950429906a7aed'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7aee'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5faed1bc84950429906a7aef'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7af0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 6},
#  {'_id': ObjectId('5faed1bc84950429906a7af1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 2},
#  {'_id': ObjectId('5faed1bc84950429906a7af2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5faed1bc84950429906a7af3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  ...]

# %%
tipo_valores = db.minas.distinct("Tipo")
list(tipo_valores)
# Out:
# ['Denúncia', 'Elogio', 'Pedido de Informação', 'Reclamação', 'Sugestão']
